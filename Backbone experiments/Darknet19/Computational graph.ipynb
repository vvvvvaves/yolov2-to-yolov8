# %%
import torch
import torch.nn as nn

# %%
import sys
sys.path.insert(1, "../../")

# %%
from Models.darknet19 import *

# %%
model = Darknet19(num_classes=10, device=None, dtype=torch.float32)

# %%
from torchviz import make_dot

# %%
img = torch.rand(1,3,224,224)
out = model(img)

# %%
make_dot(out, params=dict(model.named_parameters()))
